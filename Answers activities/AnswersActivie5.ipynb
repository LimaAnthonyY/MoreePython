# %% [markdown]
# # **Data Science Experience**
# *Prof. Orlando Junior*

# %% [markdown]
# ---

# %% [markdown]
# **Conteúdo**
#
# 1. O que é o Matplotlib?
# 2. Figuras
# 3. Gráficos
# 4. Multiplots e subplots
# 5. Exercícios

# %% [markdown]
# ---

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## O que é o Matplotlib?

# %% [markdown]
# **Matplotlib** é um das principais bibliotecas Python para visualização de dados para a criação de gráficos 2D.
#
# > **matplotlib.pyplot** é um módulo do Matplotlib para a plotagem de gráficos de forma semelhante ao MATLAB.

# %% [markdown]
# ![picture](https://matplotlib.org/stable/_images/sphx_glr_anatomy_001.png)

# %%
# Plotagem simples via numpy
x = np.arange(0, 2 * math.pi, 0.05)
y = np.sin(x)
plt.plot(x,y)

# %%
# Plotagem simples via numpy com elementos no gráfico
plt.xlabel("ângulo")        # rótulo do eixo X
plt.ylabel("seno")          # rótulo do eixo Y
plt.title('Onda senoidal')  # título do gráfico
plt.plot(x,y)
plt.show()

# %% [markdown]
# ## Figuras

# %% [markdown]
# O objeto `Figure` é um contêiner de alto nível utilizado para abranger todos os elementos de plotagem.

# %%
# Dados para plotagem
x1 = np.linspace(1, 100, 10)
x2 = np.linspace(1, 200, 10)
y = np.linspace(100, 5000, 10)

# %%
# Uso básico
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])            # [left, bottom, width, height]
linha1 = ax.plot(x1, y)                 # (x1, y)
linha2 = ax.plot(x2, y)                 # (x2, y)
plt.show()

# %%
# Parâmetros do Figure
fig = plt.figure(figsize=(10, 3),     # (width,height) em polegadas
                 dpi=72,              # Pontos por polegada (define qualidade; para plotar na web, 72dpi é bom)
                 facecolor='green',   # Cor de fundo
                 edgecolor='red',     # Cor da borda
                 linewidth=20)        # Espessura da borda
ax = fig.add_axes([0,0,1,1])
linha1 = ax.plot(x1, y)
plt.show()

# %%
# Plotagem com elementos
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
linha1 = ax.plot(x1, y)
linha2 = ax.plot(x2, y)
ax.legend(labels = ('Smartphones', 'Televisores'), loc = 'lower right')
ax.set_title("Efeito da propaganda nas vendas")
ax.set_xlabel('medium')
ax.set_ylabel('vendas')
plt.show()

# %% [markdown]
# ## Gráficos

# %% [markdown]
# **Tipos de gráfico disponíveis no matplotlib:**
# * Bar (gráfico de barras vertical);
# * Barh (gráfico de barras horizontal);
# * Boxplot;
# * Hist;
# * hist2d (histograma 2D);
# * Pie (gráfico de pizza);
# * Plot (linhas e marcadores);
# * Polar (coordenadas polares);
# * Scatter (gráfico de dispersão de x por y);
# * Stackplot (área hachurada);
# * Stem (gráfico de caule e folha);
# * Step (gráfico degrau);
# * Quiver (campos de flechas 2D).

# %% [markdown]
# **Gráfico de barras vertical**

# %%
x1 = ['C', 'C++', 'Java', 'Python', 'PHP']
y1 = np.arange(1, 6) * 10

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(x1, y1)
plt.show()

# %% [markdown]
# **Gráfico de barras agrupadas**

# %%
x2 = [[30, 25, 50, 20],
      [40, 23, 51, 17],
      [35, 22, 45, 19]]
y2 = np.arange(len(x2[0]))

# %%
y2
# Out:
# array([0, 1, 2, 3])

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(y2 + 0.00, x2[0], color = 'r', width = 0.25) # espessura
ax.bar(y2 + 0.25, x2[1], color = 'g', width = 0.25) # e
ax.bar(y2 + 0.50, x2[2], color = 'b', width = 0.25) # posição
plt.show()

# %% [markdown]
# **Gráfico de barras empilhadas**

# %%
x1 = ['C', 'C++', 'Java', 'Python', 'PHP']
m = (20, 35, 30, 35, 27)
f = (25, 32, 34, 20, 25)
idx = np.arange(5)

# %%
idx
# Out:
# array([0, 1, 2, 3, 4])

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(idx, m, 0.35, color='b')
ax.bar(idx, f, 0.35, bottom=m, color='r')
ax.set_ylabel('Pontos')
ax.set_title('Pontos por grupo e sexo')
ax.set_xticks(idx)                                    # marcação no eixo X
ax.set_xticklabels(x1)                                # texto da marcação do eixo X
ax.set_yticks(np.arange(0, 81, 10))                   # marcação no eixo Y
ax.legend(labels=['Masculino', 'Feminino'])           # legenda
plt.show()

# %% [markdown]
# **Gráfico de barras horizontal**

# %%
x1 = ['C', 'C++', 'Java', 'Python', 'PHP']
m = (20, 35, 30, 35, 27)

# %%
plt.style.use('ggplot')         # muda tudo daqui pra frente para o estilo ggplot

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.barh(x1, m)                  # (y, x)
plt.show()
# Out:
#   File "<ipython-input-89-6ab3a903d313>", line 3
#     ax.barh(, m)                  # (y, x)
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# **Boxplot**

# %%
plt.rcParams.update(plt.rcParamsDefault)      # reseta todos parâmetros do matplotlib

# %%
amostra = np.random.normal(100, 10, 200)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
bp = ax.boxplot(amostra)
plt.show()

# %% [markdown]
# **Histograma**

# %%
dados = [22,89,3,43,56,73,55,54,11,20,51,5,79,31,27]
bins = [0, 25, 50, 75, 100]                                 # bins = faixas de valores

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
h = ax.hist(dados, bins = bins)
ax.set_xticks(bins)
plt.show()

# %% [markdown]
# **Gráfico de pizza**

# %%
x1 = ['C', 'C++', 'Java', 'Python', 'PHP']
y1 = np.arange(1, 6) * 10

# %%
y1
# Out:
# array([10, 20, 30, 40, 50])

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,0.75,0.75])
ax.pie(y1, labels = x1, autopct='%.0f%%')
plt.show()

# %% [markdown]
# **Linhas e marcadores**

# %%
x = np.arange(1, 50, 1)

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 0.75, 0.75])
ax.plot(x, np.log(x), marker='v')
plt.show()

# %% [markdown]
# **Gráfico de dispersão**

# %%
m = (20, 35, 30, 35, 27)
f = (25, 32, 34, 20, 25)
idx = np.arange(5)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,0.5,0.5])
ax.scatter(idx, f, color='r')
ax.scatter(idx, m, color='b')
plt.show()

# %% [markdown]
# ## Multiplots e subplots

# %%
x = np.arange(0, math.pi*2, 0.05)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.tan(x)
y4 = np.tanh(x)

# %% [markdown]
# ***Multiple plots***

# %%
plt.plot(x, y1, color='g', label='seno')
plt.plot(x, y2, color='b', label='cosseno')
plt.plot(x, y3, color='r', label='aaa')
plt.plot(x, y4, color='y', label='tangente hiperbólica')
plt.xlabel("Ângulo")
plt.ylabel("Magnitude")
plt.legend()
plt.show()

# %% [markdown]
# ***Subplots***

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(5, 5))
ax[0, 0].plot(x, y1, label='ajsdas')
ax[0, 0].set_title("Seno", fontsize=10)

ax[0, 1].plot(x, y2)
ax[0, 1].set_title("Cosseno", fontsize=10)

ax[1, 0].plot(x, y3)
ax[1, 0].set_title("Tangente", fontsize=10)

ax[1, 1].plot(x, y4)
ax[1, 1].set_title("Tangente hiperbólica", fontsize=10)

fig.tight_layout()  # ajuste automático dos gráficos à área selecionada

plt.savefig("grafico.pdf")
plt.show()

# %% [markdown]
# ## Exercícios

# %% [markdown]
# **1 #** Plote um gráfico para a função de segundo grau
# $y=x^2 + 2x + 2$ para $x=[0, 100]$, conforme apresentado na saída.

# %%
x = np.arange(0, 100, 1)
y=x**2+2*x+2

plt.plot(x,y)

# %% [markdown]
# **2 #** Plote um gráfico para a função de terceiro grau
# $y=x^3 + 3x^2 - 2x - 1$ para $x=[0, 500]$, conforme apresentado na saída.

# %%
x = np.arange(0, 500, 1)
y=(x**3)+(3*(x**2))-(2*x)-1

plt.plot(x,y, color='orange')
plt.title('$y= x^3+3x^2−2x−1$', fontsize=21)
# Out:
# Text(0.5, 1.0, '$y= x^3+3x^2−2x−1$')

# %% [markdown]
# **3 #** Plote o gráfico da saída utilizando os dados apresentados.

# %%
x = np.linspace(0, 10, 100)
y1 = np.linspace(0, 50, 100)**2 - 100*x + 100
y2 = np.linspace(10, 20, 100)**2 + 500

# %%
plt.rcParams.update(plt.rcParamsDefault)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Dados fornecidos para plotar o gráfico
x = np.linspace(0, 10, 100)
y1 = np.linspace(0, 50, 100)**2 - 100*x + 100
y2 = np.linspace(10, 20, 100)**2 + 500

# Criação do gráfico
#plt.figure(figsize=(10, 6))
plt.plot(x, y1, color = 'blue', linestyle='dotted') # Linha tracejada azul para y1
plt.plot(x, y2, color='pink', linestyle='--') # Linha pontilhada vermelha para y2
plt.title('Y1 vs. Y2')

plt.show()

# %% [markdown]
# **4 #** Plote o gráfico da saída utilizando os dados apresentados.

# %%
x1 = np.arange(100)
y1 = np.arange(100)**2 + 2*x1

x2 = np.arange(100)
y2 = np.arange(100)*2

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(6, 3))

ax[0].plot(x1, y1, color='r', label='G1')
ax[0].set_title("Gráfico 1", fontsize=9)
ax[0].set_xticks(np.arange(False))
ax[0].legend()

ax[1].plot(x2, y2, color='b')
ax[1].set_title("Gráfico 2", fontsize=13)
ax[1].set_yticks(np.arange(False))

fig.tight_layout()  # ajuste automático dos gráficos à área selecionada

plt.savefig("grafico.pdf")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a4404a8b4f80> in <cell line: 1>()
# ----> 1 fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(6, 3))
#       2
#       3 ax[0].plot(x1, y1, color='r', label='G1')
#       4 ax[0].set_title("Gráfico 1", fontsize=9)
#       5 ax[0].set_xticks(np.arange(False))
#
# NameError: name 'plt' is not defined
